# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("..")

# %%
import cv2
import matplotlib.pyplot as plt

from src.models import TesseractOCR

# %matplotlib inline

# %%
plate_recognizer = TesseractOCR()

# %%
from src.tools import debug_ocr


debug_ocr(plate_recognizer, "../data/plates/train/img")
